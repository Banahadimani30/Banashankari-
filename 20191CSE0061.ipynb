# %% [markdown]
# <a href="https://colab.research.google.com/github/Banahadimani30/Banashankari-/blob/main/20191CSE0061.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import files
uploaded= files.upload()
import io
dataset = pd.read_csv(io.BytesIO(uploaded['20191CSE0061Banashankari.S.H5CSE02.csv']))
dataset.head(10)
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
y_pred = regressor.predict(X_train)
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years Of Experience')
plt.ylabel('Salary')
plt.show()
# Out:
#      <input type="file" id="files-43c5f0cf-f08c-4316-b53e-ed2d7cc98415" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43c5f0cf-f08c-4316-b53e-ed2d7cc98415">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 20191CSE0061Banashankari.S.H5CSE02.csv to 20191CSE0061Banashankari.S.H5CSE02.csv
